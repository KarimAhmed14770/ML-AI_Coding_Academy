# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"F:\studiess\Machine Learning and Artificial Intellignece\ML&AI_Coding_Academy\ML&AI_Repository\Python\Session7\Datasets\ca_san_diego_2019_02_25.csv")

# %%
data.head()
# Out:
#    raw_row_number        date      time service_area  subject_age  \
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0
#
#              subject_race subject_sex       type arrest_made citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   warning_issued   outcome contraband_found search_conducted search_person  \
# ...

# %%
data.tail(7)
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 390992          390993  2017-03-31  23:40:00          510         36.0
# 390993          390994  2017-03-31  23:42:00          810         26.0
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#        subject_race subject_sex       type arrest_made citation_issued  \
# 390992        black        male  vehicular       False           False
# 390993     hispanic      female  vehicular       False            True
# 390994        black        male  vehicular       False           False
# 390995     hispanic        male  vehicular         NaN            True
# ...

# %%
data.shape
# Out:
# (390999, 19)

# %%
data.dtypes
# Out:
# raw_row_number         int64
# date                  object
# time                  object
# service_area          object
# subject_age          float64
# subject_race          object
# subject_sex           object
# type                  object
# arrest_made           object
# citation_issued       object
# warning_issued        object
# outcome               object
# contraband_found      object
# search_conducted      object
# search_person         object
# search_vehicle        object
# search_basis          object
# reason_for_search     object
# reason_for_stop       object
# dtype: object

# %%
data.isnull().sum()
# Out:
# raw_row_number            0
# date                    132
# time                   1256
# service_area              0
# subject_age           12644
# subject_race           1398
# subject_sex             806
# type                      0
# arrest_made           35022
# citation_issued       32712
# warning_issued        32712
# outcome               40047
# contraband_found     379835
# search_conducted      37096
# search_person        376459
# search_vehicle       376459
# search_basis         374173
# reason_for_search    376343
# reason_for_stop         266
# dtype: int64

# %%
data.columns
# Out:
# Index(['raw_row_number', 'date', 'time', 'service_area', 'subject_age',
#        'subject_race', 'subject_sex', 'type', 'arrest_made', 'citation_issued',
#        'warning_issued', 'outcome', 'contraband_found', 'search_conducted',
#        'search_person', 'search_vehicle', 'search_basis', 'reason_for_search',
#        'reason_for_stop'],
#       dtype='object')

# %%
data.date.head()
# Out:
# 0    2014-01-01
# 1    2014-01-01
# 2    2014-01-01
# 3    2014-01-01
# 4    2014-01-01
# Name: date, dtype: object

# %%
data["time"].head()
# Out:
# 0    01:25:00
# 1    05:47:00
# 2    07:46:00
# 3    08:10:00
# 4    08:35:00
# Name: time, dtype: object

# %%
data.time.head()
# Out:
# 0    01:25:00
# 1    05:47:00
# 2    07:46:00
# 3    08:10:00
# 4    08:35:00
# Name: time, dtype: object

# %%
data[["date","time"]].head()
# Out:
#          date      time
# 0  2014-01-01  01:25:00
# 1  2014-01-01  05:47:00
# 2  2014-01-01  07:46:00
# 3  2014-01-01  08:10:00
# 4  2014-01-01  08:35:00

# %%
data.columns=data.columns.str.capitalize()

# %%
data.head()
# Out:
#    Raw_row_number        Date      Time Service_area  Subject_age  \
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0
#
#              Subject_race Subject_sex       Type Arrest_made Citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   Warning_issued   Outcome Contraband_found Search_conducted Search_person  \
# ...

# %%
data.rename(columns={"Date":"DATE","Time":"TIME"},inplace=True)
data.head()
# Out:
#    Raw_row_number        DATE      TIME Service_area  Subject_age  \
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0
#
#              Subject_race Subject_sex       Type Arrest_made Citation_issued  \
# 0                   white        male  vehicular       False            True
# 1                   white        male  vehicular       False           False
# 2  asian/pacific islander        male  vehicular       False           False
# 3                   white        male  vehicular       False            True
# 4                hispanic        male  vehicular       False            True
#
#   Warning_issued   Outcome Contraband_found Search_conducted Search_person  \
# ...

# %%
data.iloc[0].head()
# Out:
# Raw_row_number             1
# DATE              2014-01-01
# TIME                01:25:00
# Service_area             110
# Subject_age             24.0
# Name: 0, dtype: object

# %%
data.iloc[0,1]
# Out:
# '2014-01-01'

# %%
data.iloc[0,[1,3,5]]
# Out:
# DATE            2014-01-01
# Service_area           110
# Subject_race         white
# Name: 0, dtype: object

# %%
data.iloc[0:5,[1,3,5]]
# Out:
#          DATE Service_area            Subject_race
# 0  2014-01-01          110                   white
# 1  2014-01-01          320                   white
# 2  2014-01-01          320  asian/pacific islander
# 3  2014-01-01          610                   white
# 4  2014-01-01          930                hispanic

# %%
data.iloc[0:5,0:5]
# Out:
#    Raw_row_number        DATE      TIME Service_area  Subject_age
# 0               1  2014-01-01  01:25:00          110         24.0
# 1               2  2014-01-01  05:47:00          320         42.0
# 2               3  2014-01-01  07:46:00          320         29.0
# 3               4  2014-01-01  08:10:00          610         23.0
# 4               5  2014-01-01  08:35:00          930         35.0

# %%
data.loc[1:5,"TIME":"Type"]
# Out:
#        TIME Service_area  Subject_age            Subject_race Subject_sex  \
# 1  05:47:00          320         42.0                   white        male
# 2  07:46:00          320         29.0  asian/pacific islander        male
# 3  08:10:00          610         23.0                   white        male
# 4  08:35:00          930         35.0                hispanic        male
# 5  08:39:00          820         30.0                hispanic        male
#
#         Type
# 1  vehicular
# 2  vehicular
# 3  vehicular
# 4  vehicular
# 5  vehicular

# %%
data.dropna(axis="columns",how="all").shape
# Out:
# (390999, 19)

# %%
data.dropna(axis="columns", how="any").shape
# Out:
# (390999, 3)

# %%
data.Reason_for_stop.value_counts().head()
# Out:
# Reason_for_stop
# Moving Violation                285562
# Equipment Violation              99577
# Radio Call/Citizen Contact        1941
# Muni, County, H&S Code            1349
# Personal Knowledge/Informant       884
# Name: count, dtype: int64

# %%
data[data.Reason_for_stop=="Moving Violation"].Subject_sex.value_counts()
# Out:
# Subject_sex
# male      179242
# female    105765
# Name: count, dtype: int64

# %%
data[data.Subject_sex==
   "female"
  ].Reason_for_stop.value_counts(
    normalize=True).head()
# Out:
# Reason_for_stop
# Moving Violation                0.773651
# Equipment Violation             0.215736
# Radio Call/Citizen Contact      0.003606
# Muni, County, H&S Code          0.002516
# Personal Knowledge/Informant    0.001609
# Name: proportion, dtype: float64
